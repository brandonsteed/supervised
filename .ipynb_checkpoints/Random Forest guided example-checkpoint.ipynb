# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Replace the path with the correct path for your data.
y2015 = pd.read_csv('LoanStats3d.csv',
    skipinitialspace=True,
    header=1
)
# Out:
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
y2015.head()
# Out:
#          id   member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68009401  72868139.0    16000.0      16000.0          16000.0   60 months
# 1  68354783  73244544.0     9600.0       9600.0           9600.0   36 months
# 2  68466916  73356753.0    25000.0      25000.0          25000.0   36 months
# 3  68466961  73356799.0    28000.0      28000.0          28000.0   36 months
# 4  68495092  73384866.0     8650.0       8650.0           8650.0   36 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0   14.85%       379.39     C        C5            ...
# 1    7.49%       298.58     A        A4            ...
# 2    7.49%       777.55     A        A4            ...
# 3    6.49%       858.05     A        A2            ...
# 4   19.89%       320.99     E        E3            ...
#
#   num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                0.0                2.0           78.9               0.0
# 1                0.0                2.0          100.0              66.7
# 2                0.0                0.0          100.0              20.0
# 3                0.0                0.0           91.7              22.2
# 4                0.0               12.0          100.0              50.0
#
#   pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                  0.0       2.0        298100.0           31329.0
# 1                  0.0       0.0         88635.0           55387.0
# 2                  0.0       0.0        373572.0           68056.0
# 3                  0.0       0.0        304003.0           74920.0
# 4                  1.0       0.0         38998.0           18926.0
#
#   total_bc_limit total_il_high_credit_limit
# 0       281300.0                    13400.0
# 1        12500.0                    75635.0
# 2        38400.0                    82117.0
# 3        41500.0                    42503.0
# 4         2750.0                    18248.0
#
# [5 rows x 111 columns]

# %%
categorical = y2015.select_dtypes(include=['object'])
for i in categorical:
    column = categorical[i]
    print(i)
    print(column.nunique())
# Out:
# id
# 421097
# term
# 2
# int_rate
# 110
# grade
# 7
# sub_grade
# 35
# emp_title
# 120812
# emp_length
# 11
# home_ownership
# 4
# verification_status
# 3
# issue_d
# 12
# loan_status
# 7
# pymnt_plan
# 1
# url
# 421095
# desc
# 34
# purpose
# 14
# title
# 27
# zip_code
# 914
# addr_state
# 49
# earliest_cr_line
# 668
# revol_util
# 1211
# initial_list_status
# 2
# last_pymnt_d
# 25
# next_pymnt_d
# 4
# last_credit_pull_d
# 26
# application_type
# 2
# verification_status_joint
# 3

# %%
# Convert ID and Interest Rate to numeric.
y2015['id'] = pd.to_numeric(y2015['id'], errors='coerce')
y2015['int_rate'] = pd.to_numeric(y2015['int_rate'].str.strip('%'), errors='coerce')

# Drop other columns with many unique variables
y2015.drop(['url', 'emp_title', 'zip_code', 'earliest_cr_line', 'revol_util',
            'sub_grade', 'addr_state', 'desc'], 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-56f81792a534> in <module>()
#       1 # Convert ID and Interest Rate to numeric.
#       2 y2015['id'] = pd.to_numeric(y2015['id'], errors='coerce')
# ----> 3 y2015['int_rate'] = pd.to_numeric(y2015['int_rate'].str.strip('%'), errors='coerce')
#       4
#       5 # Drop other columns with many unique variables
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\accessor.py in __get__(self, instance, owner)
#      52             # this ensures that Series.str.<method> is well defined
#      53             return self.accessor_cls
# ---> 54         return self.construct_accessor(instance)
#      55
#      56     def __set__(self, instance, value):
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\strings.py in _make_accessor(cls, data)
#    1908             # (instead of test for object dtype), but that isn't practical for
#    1909             # performance reasons until we have a str dtype (GH 9343)
# -> 1910             raise AttributeError("Can only use .str accessor with string "
#    1911                                  "values, which use np.object_ dtype in "
#    1912                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
y2015.tail()
# Out:
#                 id   member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 421092  36271333.0  38982739.0    13000.0      13000.0          13000.0
# 421093  36490806.0  39222577.0    12000.0      12000.0          12000.0
# 421094  36271262.0  38982659.0    20000.0      20000.0          20000.0
# 421095         NaN         NaN        NaN          NaN              NaN
# 421096         NaN         NaN        NaN          NaN              NaN
#
#               term  int_rate  installment grade sub_grade  \
# 421092   60 months     15.99       316.07     D        D2
# 421093   60 months     19.99       317.86     E        E3
# 421094   36 months     11.99       664.20     B        B5
# 421095         NaN       NaN          NaN   NaN       NaN
# 421096         NaN       NaN          NaN   NaN       NaN
#
#                   ...             num_tl_90g_dpd_24m num_tl_op_past_12m  \
# 421092            ...                            0.0                3.0
# 421093            ...                            1.0                2.0
# 421094            ...                            0.0                1.0
# 421095            ...                            NaN                NaN
# 421096            ...                            NaN                NaN
#
#        pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies tax_liens  \
# 421092          100.0              50.0                  1.0       0.0
# 421093           95.0              66.7                  0.0       0.0
# 421094          100.0              50.0                  0.0       1.0
# 421095            NaN               NaN                  NaN       NaN
# 421096            NaN               NaN                  NaN       NaN
#
#        tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 421092         51239.0           34178.0        10600.0
# 421093         96919.0           58418.0         9700.0
# 421094         43740.0           33307.0        41700.0
# 421095             NaN               NaN            NaN
# 421096             NaN               NaN            NaN
#
#        total_il_high_credit_limit
# 421092                    33239.0
# 421093                    69919.0
# 421094                        0.0
# 421095                        NaN
# 421096                        NaN
#
# [5 rows x 111 columns]

# %%
# Remove two summary rows at the end that don't actually contain data.
y2015 = y2015[:-2]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-d95eadeb2b47> in <module>()
#       1 # Remove two summary rows at the end that don't actually contain data.
# ----> 2 y2015 = y2015[:-2]
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2127         indexer = convert_to_index_sliceable(self, key)
#    2128         if indexer is not None:
# -> 2129             return self._getitem_slice(indexer)
#    2130
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in _getitem_slice(self, key)
#    2154
#    2155     def _getitem_slice(self, key):
# -> 2156         return self._slice(key, axis=0)
#    2157
#    2158     def _getitem_array(self, key):
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis, kind)
#    1942         """
#    1943         axis = self._get_block_manager_axis(axis)
# -> 1944         result = self._constructor(self._data.get_slice(slobj, axis=axis))
#    1945         result = result.__finalize__(self)
#    1946
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in get_slice(self, slobj, axis)
#    3627         bm = self.__class__(new_blocks, new_axes, do_integrity_check=False,
#    3628                             fastpath=True)
# -> 3629         bm._consolidate_inplace()
#    3630         return bm
#    3631
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _consolidate_inplace(self)
#    3829     def _consolidate_inplace(self):
#    3830         if not self.is_consolidated():
# -> 3831             self.blocks = tuple(_consolidate(self.blocks))
#    3832             self._is_consolidated = True
#    3833             self._known_consolidated = True
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _consolidate(blocks)
#    4851     for (_can_consolidate, dtype), group_blocks in grouper:
#    4852         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4853                                       _can_consolidate=_can_consolidate)
#    4854         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4855     return new_blocks
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    4871         # combination of those slices is a slice, too.
#    4872         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 4873         new_values = _vstack([b.values for b in blocks], dtype)
#    4874
#    4875         argsort = np.argsort(new_mgr_locs)
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\internals.py in _vstack(to_stack, dtype)
#    4917
#    4918     else:
# -> 4919         return np.vstack(to_stack)
#    4920
#    4921
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     232
#     233     """
# --> 234     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     235
#     236 def hstack(tup):
#
# MemoryError:

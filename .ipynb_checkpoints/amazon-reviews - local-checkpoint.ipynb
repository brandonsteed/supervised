# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import time
from sklearn.model_selection import cross_val_score

# %%
toys1 = pd.read_json('Toys_and_Games_5.json', lines=True)
toys = toys1.loc[np.random.choice(toys1.index, 50000, replace=False)].reindex()

# %%
toys['overall'].hist()

# %%
toys['positive_rating'] = np.where(toys.overall >=4, 1, 0)

# %%
toys
# Out:
#               asin   helpful  overall  \
# 102565  B004Y8TF96    [0, 2]        5
# 43307   B000TTOCH4    [2, 2]        5
# 119004  B0075XNGGK    [1, 1]        5
# 19647   B0002HWFV8    [0, 0]        5
# 145458  B00B1Z6FKW    [0, 0]        4
# 51555   B0017JBR6O    [0, 0]        5
# 160161  B00DKCI1P6    [0, 0]        5
# 113874  B006IMX18W    [0, 0]        5
# 113277  B006CDDW4A    [2, 2]        5
# 136927  B0094J4NLA    [0, 0]        5
# 159871  B00DH7P73S    [0, 0]        5
# 117106  B006UD2RB6    [0, 0]        5
# 141258  B00A8E5GI4    [0, 0]        5
# 88704   B00491ORGO    [0, 0]        5
# 148411  B00BQYQY8Q    [1, 2]        5
# 155213  B00CKH9IIQ    [0, 0]        5
# 113099  B006CD33AI    [1, 2]        4
# 18936   B000296LSO    [0, 0]        2
# 36919   B000LFUKCM    [0, 0]        5
# 117812  B006YWI5QY    [0, 0]        5
# 131403  B008AG5VOQ    [3, 5]        5
# 96205   B004P940TY    [3, 3]        4
# 116934  B006TTK7VI  [30, 31]        5
# 121497  B007GE75G0    [0, 0]        5
# 150940  B00C6BWA8Q    [0, 0]        1
# 154080  B00CI6J1XG    [0, 0]        4
# 58815   B001TE5C1S    [1, 1]        1
# 122974  B007KJECSU    [0, 0]        4
# 15610   B00009XNSY    [1, 2]        5
# 90895   B004GHNFKK    [0, 0]        4
# ...            ...       ...      ...
# 78170   B003DJ3A5W    [0, 0]        5
# 80858   B003M2KPE4    [3, 3]        3
# 158700  B00CYFUWGG    [2, 3]        3
# 158369  B00CXEXNL4   [1, 12]        3
# 10315   B00005RF5D    [0, 0]        2
# 159178  B00D7OAOYI    [0, 0]        3
# 78773   B003ESOHSQ    [2, 2]        5
# 52026   B0018QQQEO    [0, 0]        2
# 35772   B000J52AHW    [1, 1]        5
# 66394   B002NPBT50    [0, 1]        4
# 29636   B000EUHKUE    [0, 0]        5
# 94005   B004MWN1AS    [0, 0]        5
# 119306  B0076VIZBW    [0, 0]        5
# 19222   B0002CYPO8    [1, 1]        5
# 744     0980223644    [1, 1]        5
# 155059  B00CJO90ZG    [4, 5]        4
# 3242    B00000ISC5    [0, 0]        5
# 14093   B00008W72D    [0, 0]        5
# 34431   B000HDH57G    [0, 0]        5
# 70331   B0031ES9LE    [0, 0]        5
# 148351  B00BQIVO2S    [0, 0]        5
# 73452   B00383AEZW    [0, 0]        5
# 59483   B001UEWH9W    [0, 0]        5
# 47705   B0013BL3LK    [0, 0]        5
# 64934   B002IMMDN0    [0, 0]        1
# 91938   B004INGVHQ    [0, 0]        4
# 134379  B008J4IR9U    [0, 1]        5
# 139853  B009Y94H1G    [1, 1]        5
# 126989  B007XVYT1A    [0, 0]        5
# 57625   B001QHHZ72    [0, 0]        4
#
#                                                reviewText   reviewTime  \
# 102565  I bought this for my 11month old baby and she ...  01 18, 2013
# 43307   Thank you so much! My 9 year old has been writ...  02 13, 2013
# 119004  We have a preschooler and a first grader and t...  10 17, 2013
# 19647   This is a beautiful, well-made, sturdy puzzle ...  05 24, 2012
# 145458  I have been an avid birder for several decades...  12 18, 2013
# 51555   This kitchen is perfect. The assembly took a l...  12 22, 2012
# 160161                                         great toy!  07 14, 2014
# 113874  my son loves themeasy for little ones to work ...   03 5, 2013
# 113277  My three year old you has recently seen the Av...  05 16, 2012
# 136927  My daughter got this for Christmas and since I...  01 16, 2014
# 159871  This EVER AFTER HIGH SECRET HEARTS PASSWORD JO...   03 8, 2014
# 117106  Kid loved them for a stocking stuffer last Xma...  03 11, 2013
# 141258  My 6 year old son loves everything that has to...  12 25, 2013
# 88704   My son enjoys the Cars movie so he likes the g...   11 5, 2012
# 148411  My son is really into super heroes and especia...  07 25, 2013
# 155213  This Barbie doll is so much fun.  You can make...   01 3, 2014
# 113099  The Robots In Disguise Arcee figure is a prett...  01 22, 2013
# 18936   The set had no storage box nor stand. Loose to...  07 12, 2014
# 36919   This has been fun for both the one year old an...  01 17, 2010
# 117812  Bananagrams, Scrabble, Words with Friends - an...  03 19, 2012
# 131403  We bought this for our tall (39&#34;) 2 yr old...  02 12, 2013
# 96205   We bought this for our daughter for x-mas and ...  05 25, 2012
# 116934  We own both theMelissa & Doug 60-Piece Standar...  06 30, 2013
# 121497  Little hands love these.  They are easy to sna...  04 16, 2014
# 150940  I would recommend this for a much younger chil...  06 20, 2014
# 154080  Crayola Jewelry Boutique Neon provides some fu...  11 25, 2013
# 58815   In celebration of the ODST, McFarlane releases...   05 2, 2010
# 122974  I like how sturdy it is. It lasted put togethe...  03 20, 2013
# 15610   For quite some time I've been searching for a ...  11 12, 2009
# 90895   It works but it does require a good amount of ...  10 28, 2013
# ...                                                   ...          ...
# 78170   This item maneuvers well and my kids love it. ...  06 30, 2013
# 80858   I ordered 8 of these for my two boys, and they...  12 27, 2011
# 158700  My 8 year old received this for Christmas and ...  12 29, 2013
# 158369  My family loves to play board and card games. ...  10 23, 2013
# 10315   This toy looks cute and the reviews raved abou...  12 27, 2013
# 159178  I loved this game as a child. And while the ga...  05 16, 2014
# 78773   This is very fun to add your own style both wi...  12 30, 2010
# 52026   My daughter was looking foward to getting one ...  01 13, 2009
# 35772   I despise the price of these Thomas pieces and...  02 13, 2013
# 66394   We haven't really sat down and studied this ga...  01 13, 2013
# 29636   My daughter got one from Santa and my son was ...  04 24, 2013
# 94005   The pages have different parts to activate dep...   01 4, 2013
# 119306  A LIFE SAVER!  If it weren't for this, I would...  12 12, 2013
# 19222   Excellent German craftsmanship.  Great attenti...   01 4, 2014
# 744     Say Anything: 3-8 Players, Ages 10+, Average P...   01 8, 2014
# 155059  When I first saw the Thomas and Friends: Real ...  07 22, 2013
# 3242    I got this for my eight, six, and four year ol...  09 20, 2011
# 14093   My son received these for his first birthday. ...   07 7, 2009
# 34431   My 4 month old granddaughter will grow into th...  12 28, 2012
# 70331   This was a gift for my 8 year old son and he l...   04 9, 2014
# 148351  Our family loves these puzzles. It's fun to wo...  04 21, 2014
# 73452   Got this for the kids, for an outdoor toy that...   04 8, 2012
# 59483   This game is great for little kids.  My 2 and ...  12 20, 2010
# 47705   I love that I have something to help teach abo...  01 27, 2014
# 64934   The plastic should of been built better. But f...   01 3, 2014
# 91938   I played HyperSwipe with some of my nephews (r...   12 4, 2011
# 134379  I am not a big fan of the Lantern Corps but my...  05 10, 2014
# 139853  Michones pet number two.  Collect the main fig...   05 6, 2013
# 126989  My son bought all four of the switch and go di...  12 31, 2012
# 57625   This was a Christmas present for my 6 year-old...   01 7, 2010
#
#             reviewerID                               reviewerName  \
# 102565  A3H0FPX8POP4WL                                 A. Roberts
# 43307   A2N9ZKPXQGMX37                                     Kristi
# 119004   A4EBYIKOMYFF9                        E. Von Der Scratchy
# 19647   A2HOLM5I1ARX9J                         Carol C. "ccjello"
# 145458  A17HMM1M7T9PJ1                           Timothy B. Riley
# 51555    AXQ1EZSGM281P                       Got an A in Shopping
# 160161   AE9H83YV1VU2G                                        jwb
# 113874  A2WVRAWNXC5DHP                                         KK
# 113277   ASB791WMVDIX0                                  Elizabeth
# 136927   A44V99PXB7RCZ             K. Rosado "Your Call For Help"
# 159871   ARTI9VVJS9CZQ                                      cathy
# 117106  A1WJV6LHZUMFQN                                      Roger
# 141258  A1Y2R2TOJJEOE3                                       K.B.
# 88704    AFTRQTNS1YRM8                                 Marie Ross
# 148411   ABYLSNI0MGXZB    SweetHappyLife-com "SweetHappyLife-com"
# 155213  A2EJ9H2VQPTJ0V                                       Mimi
# 113099  A2SBWW3UKUNVAO                                  Autobot12
# 18936   A38LWVIGK6FHAR                                        NaN
# 36919   A1JEZWLIOEMI7Z                                  Waterdiva
# 117812  A2UVYCQOY2756H                                 Game Lover
# 131403   AFXMFSYC1P8UA                              Kristin Tripp
# 96205     A11JYH0QXNOI                            Julie M. Lowery
# 116934  A2JKM8KF3296CW                          Ninjaba "Ninjaba"
# 121497  A2EQLG2PJNQFAG                              KJ "K Clay J"
# 150940  A2PNW6QDW8OPY0                              Faith Webster
# 154080  A2PD27UKAD3Q00       Wilhelmina Zeitgeist "coolartsybabe"
# 58815   A25OJH02IZ86EP                       James Lee Owings III
# 122974  A30YX9UGGD1HJC              Living at the Whitehead's Zoo
# 15610    AS4R3I9KU5JVH                                   Dobrin'a
# 90895   A3JGYZ1COZN0G2                                Buschchris1
# ...                ...                                        ...
# 78170   A1YVO1GWUM1Z6I                                  Mickeylee
# 80858   A2XPT8ZZH17XGW                            Jeannette Davis
# 158700  A1430IT4XVIZ37                                   Charfish
# 158369  A2VVBH89DH97XA                                     jimbon
# 10315   A37T6ETQ1446UH                                  Grandma M
# 159178  A16ZFIHH9QSC0E                                  bgraves81
# 78773   A1EC0N43JWJ7R3                       OnlineShoppingIsBest
# 52026   A105ME60VV2K2W                         Cristina I. Wright
# 35772    A6OQWTBDN4TII                            Amazon Customer
# 66394   A2W7ELGTCQ0UOQ                             Stacy Isermann
# 29636    APDDEDYUPDYOE                                     Tracee
# 94005   A11IFBSF8AMW9M                                   Christen
# 119306  A2CEUUD4H3JV8D                              wayne vincent
# 19222    AB9KKOL8QD0F9                                  N. Caputo
# 744     A1UP19XQH91JT0                     Dad's Gaming Addiction
# 155059   ARNEUO7BF3J55                              E. David Swan
# 3242    A17SZZO9LM3WYC  Mayflower Girl "amazon-junkie since 1996"
# 14093   A11K2HXZB4Z1VY                                   J. Blair
# 34431   A3NV53Q5KT8QC9                               B. Stensgard
# 70331    AJY3X30AQE0CW                            Melissa M. Hess
# 148351  A3KMM68QLUAFU6                                  SwissMiss
# 73452   A2P65SKPDZDEUZ                            Amazon Customer
# 59483   A1M8AYAL3L8ACP                            Amanda L. Davis
# 47705   A1VROSP8YSWDGE                            Maggie Anderson
# 64934    AQKYCTBIIKP47                               Krista Scott
# 91938   A2HXAF4GIH6S85                              Brett Kuehner
# 134379  A1T8FE0392B74W                                         JN
# 139853  A22YTQWCR52OIW                              Wil Character
# 126989  A2R6688OH0M12T                      R. Berger "Mama of 2"
# 57625   A2PAA7HMWV76F0                                   hbehling
#
#                                                   summary  unixReviewTime  \
# 102565                                Absolutely love it!      1358467200
# 43307                             MADE MY DAUGHTER'S DAY!      1360713600
# 119004                        we can all play together :)      1381968000
# 19647   Fabulous trip to Germany without leaving Kansa...      1337817600
# 145458  The binoculars could be better but at least it...      1387324800
# 51555                                             Perfect      1356134400
# 160161                                         Five Stars      1405296000
# 113874                                              great      1362441600
# 113277                          My 3 year old loves this!      1337126400
# 136927                                         Super Easy      1389830400
# 159871                                  Very Magical !!!!      1394236800
# 117106                                      Great bargain      1362960000
# 141258                                 Great Xmas present      1387929600
# 88704                                Cars 2 Tag Storybook      1352073600
# 148411                            3 1/2 Year Old Loves It      1374710400
# 155213                                     Dancing Lights      1388707200
# 113099                            Arcee is a cool figure.      1358812800
# 18936                               Loose towers for keep      1405123200
# 36919                            magnetic puzzles are fun      1263686400
# 117812                      Take this word game anywhere!      1332115200
# 131403                                           Perfect!      1360627200
# 96205            My daughter really likes this collection      1337904000
# 116934  Great set. Comparable to Melissa and Doug's 60...      1372550400
# 121497                   Great "Legos" that are not legos      1397606400
# 150940                                  Not that exciting      1403222400
# 154080    Makes Some Pretty Cool And Unique Looking Beads      1385337600
# 58815       Save your money, or just leave it in the box!      1272758400
# 122974                     Great toy for Chuggington Fans      1363737600
# 15610                                              Great.      1257984000
# 90895                                        Cool i guess      1382918400
# ...                                                   ...             ...
# 78170                                           Great buy      1372550400
# 80858                                       Boys love it!      1324944000
# 158700                            Scary for my 8 year old      1388275200
# 158369               Some Like It Some Do Not - Operation      1382486400
# 10315                  Cute but not very fun to play with      1388102400
# 159178                       Flimsy, Cheaply Made Version      1400198400
# 78773             GREAT FOR MANY AGES AND ARTISTIC LEVELS      1293667200
# 52026                             rescue pet swimming dog      1231804800
# 35772                                    Pricey but great      1360713600
# 66394                                      Crazy fun Maze      1358035200
# 29636                                          It's cute.      1366761600
# 94005                   So many ways to use this book set      1357257600
# 119306                                      A LIFE SAVER!      1386806400
# 19222                                              Bruder      1388793600
# 744     Say Anything & Say Anything Family Review by D...      1389139200
# 155059  Good Toy for the Budget Conscious Parent of a ...      1374451200
# 3242            I was a doubter...but I was totally WRONG      1316476800
# 14093                           Great bang for your block      1246924800
# 34431                                               great      1356652800
# 70331                                     Fun little guy!      1397001600
# 148351                  Another fun White Mountain puzzle      1398038400
# 73452                                       Kids love it!      1333843200
# 59483                          Great Game for Little Ones      1292803200
# 47705                                 The kids LOVE this!      1390780800
# 64934    this is not exactly what i thought i was getting      1388707200
# 91938                        Fast-paced and easy to learn      1322956800
# 134379                            No real complaints here      1399680000
# 139853                                 Pet two the sequel      1367798400
# 126989                                            fun toy      1356912000
# 57625                                       Son loves it!      1262822400
#
#         positive_rating
# 102565                1
# 43307                 1
# 119004                1
# 19647                 1
# 145458                1
# 51555                 1
# 160161                1
# 113874                1
# 113277                1
# 136927                1
# 159871                1
# 117106                1
# 141258                1
# 88704                 1
# 148411                1
# 155213                1
# 113099                1
# 18936                 0
# 36919                 1
# 117812                1
# 131403                1
# 96205                 1
# 116934                1
# 121497                1
# 150940                0
# 154080                1
# 58815                 0
# 122974                1
# 15610                 1
# 90895                 1
# ...                 ...
# 78170                 1
# 80858                 0
# 158700                0
# 158369                0
# 10315                 0
# 159178                0
# 78773                 1
# 52026                 0
# 35772                 1
# 66394                 1
# 29636                 1
# 94005                 1
# 119306                1
# 19222                 1
# 744                   1
# 155059                1
# 3242                  1
# 14093                 1
# 34431                 1
# 70331                 1
# 148351                1
# 73452                 1
# 59483                 1
# 47705                 1
# 64934                 0
# 91938                 1
# 134379                1
# 139853                1
# 126989                1
# 57625                 1
#
# [50000 rows x 10 columns]

# %%
#df = toys[['reviewText', 'positive_rating']]

# %%
toys['positive_rating'] = (toys['positive_rating'] == 1)

# %%
toys['reviewText'] = toys.reviewText.str.replace(r'[^a-zA-Z\d\s:]', '')
toys['reviewText'] = toys['reviewText'].str.lower()

pos_words = toys.reviewText[toys.overall].str.cat(sep=' ').split()

neg_words = toys.reviewText[toys.overall == False].str.cat(sep=' ').split()
# Out:
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\series.py:696: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]

# %%
# Unique Words
print('negative:', len(np.unique(neg_words)), ' positive:', len(np.unique(pos_words)))
# Out:
# negative: 0  positive: 29

# %%
keywords = pd.Series(neg_words).value_counts().keys().ravel()

keywords
# Out:
# array([], dtype=float64)

# %%
diff = np.setdiff1d(
        ar1=pd.Series(pos_words).value_counts().keys().ravel(), 
                      ar2=pd.Series(neg_words).value_counts().keys().ravel()
                     )
diff
# Out:
# array(['a', 'additional', 'and', 'around', 'board', 'bought', 'carry',
#        'doug', 'for', 'from', 'hope', 'increase', 'is', 'it', 'kids',
#        'letter', 'magnetic', 'mellissa', 'nice', 'pieces', 'play', 'the',
#        'them', 'thier', 'this', 'time', 'to', 'with', 'works'],
#       dtype=object)

# %%
new = toys
keywords = diff

for key in keywords:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    new[str(key)] = new.reviewText.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

X = new[keywords]
y = new['positive_rating']

# %%
time1 = time.time()

# Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# Fit our model to the data.
bnb.fit(X, y)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(X)

# %%
cross_val_score(bnb, X, y, cv=5)
# Out:
# array([0.83821618, 0.8381    , 0.8374    , 0.8378    , 0.83808381])

# %%
print('Naive Bayes runtime')
print('--- %s seconds ---' % (time.time() - time1))
# Out:
# Naive Bayes runtime
# --- 0.3855283260345459 seconds ---

# %%
time2 = time.time()

from sklearn.svm import SVC
svc = SVC()

X = new[keywords]
y = new['positive_rating']

svc.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
cross_val_score(svc, X, y, cv=5)
# Out:
# array([0.83811619, 0.8381    , 0.8381    , 0.8381    , 0.83818382])

# %%
print('SVM runtime')
print('--- %s seconds ---' % (time.time() - time2))
# Out:
# SVM runtime
# --- 827.8105344772339 seconds ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import time
from sklearn.model_selection import cross_val_score

# %%
toys1 = pd.read_json('Toys_and_Games_5.json', lines=True)
toys = toys1.loc[np.random.choice(toys1.index, 20000, replace=False)].reindex()

# %%
toys['overall'].hist()

# %%
toys['positive_rating'] = np.where(toys.overall >=4, 1, 0)

# %%
toys
# Out:
#               asin   helpful  overall  \
# 48229   B001447IX8    [0, 0]        5
# 41242   B000OWAZYU    [0, 0]        5
# 141526  B00A8UT55I    [0, 0]        5
# 64922   B002IMFN3C    [0, 0]        5
# 124487  B007RDGHPU    [1, 2]        4
# 110009  B005VPRE3K    [0, 0]        5
# 110865  B005XVCR48    [0, 0]        5
# 7844    B00004UFOO    [0, 0]        5
# 101505  B004UU9ZAW    [1, 1]        4
# 30502   B000F8T026    [0, 2]        5
# 58082   B001RBWY14    [0, 0]        5
# 144583  B00AWNUHB2    [0, 0]        3
# 109485  B005UWYK22    [0, 0]        4
# 75016   B0038OMF30    [0, 0]        1
# 100030  B004TGPQDW    [0, 0]        2
# 161692  B00E3ECKGG    [0, 0]        3
# 97874   B004R1ZUNA    [0, 0]        4
# 66152   B002NGKQEY    [0, 0]        5
# 124504  B007RDGKK2    [0, 0]        4
# 80959   B003MB6224    [0, 1]        1
# 72473   B003774W6Q    [2, 4]        5
# 126525  B007XVYO1K    [0, 0]        4
# 36325   B000KICMWQ    [0, 0]        5
# 33205   B000GKXY66    [1, 1]        5
# 3538    B00000IUT7    [0, 0]        4
# 5462    B00000J58X    [0, 0]        5
# 138320  B009JBCF5Y    [0, 0]        5
# 88202   B004774X5U  [12, 13]        5
# 20149   B0002Q2O9C    [0, 0]        3
# 144167  B00ATWSRG8    [0, 0]        5
# ...            ...       ...      ...
# 36217   B000K8FYAS    [0, 0]        5
# 136049  B008TCH6XK    [0, 0]        4
# 24464   B0009I8NR0    [0, 0]        5
# 146539  B00BBLCYH4    [0, 0]        4
# 136915  B00946ZOT8    [6, 6]        5
# 81052   B003MS6150    [0, 0]        5
# 87615   B0045O4Q4S    [0, 0]        5
# 55193   B001H31UOY    [0, 0]        4
# 128511  B0083TXXZ4    [2, 2]        3
# 126306  B007XJE0W0    [0, 0]        4
# 80809   B003LQMSKK    [0, 0]        4
# 138096  B009F7OWF8    [1, 2]        3
# 65390   B002KE5OZ0    [1, 1]        4
# 64471   B002ERB4O8    [0, 0]        5
# 54289   B001ECKJJ0    [0, 0]        5
# 153096  B00CE61H64    [0, 1]        5
# 151098  B00C6PSBE4    [0, 0]        3
# 55252   B001HBCXLU    [0, 0]        5
# 155735  B00CM5D86Y    [0, 0]        5
# 105006  B0055B7YLM    [0, 0]        3
# 163435  B00EY2706C    [0, 0]        4
# 32311   B000GEALZO    [0, 0]        5
# 124629  B007RM5AJK    [0, 0]        5
# 167484  B00J49UTW2    [0, 1]        3
# 2622    B00000DMD2    [0, 0]        5
# 54329   B001EHEH9S    [0, 0]        5
# 12935   B00007FY4H    [1, 2]        4
# 5355    B00000J4SP    [0, 0]        3
# 104581  B0053FJK8K    [0, 0]        5
# 103378  B004Z7H2EQ    [0, 0]        5
#
#                                                reviewText   reviewTime  \
# 48229   I saw a huge improvement on my toddler's fine ...  01 29, 2014
# 2622                          One of our kids' favorites!      1257897600
# 54329                                    Excellent choice      1379030400
# 12935                                               Great      1303084800
# 5355                                         Limited use?      1042502400
# 104581                                Super Fun Bath toy!      1389225600
# 103378                             Leap Pad download card      1357344000
#
#         positive_rating
# 48229                 1
# 41242                 1
# 141526                1
# 64922                 1
# 124487                1
# 110009                1
# 110865                1
# 7844                  1
# 101505                1
# 30502                 1
# 58082                 1
# 144583                0
# 109485                1
# 75016                 0
# 100030                0
# 161692                0
# 97874                 1
# 66152                 1
# 124504                1
# 80959                 0
# 72473                 1
# 126525                1
# 36325                 1
# 33205                 1
# 3538                  1
# 5462                  1
# 138320                1
# 88202                 1
# 20149                 0
# 144167                1
# ...                 ...
# 36217                 1
# 136049                1
# 24464                 1
# 146539                1
# 136915                1
# 81052                 1
# 87615                 1
# 55193                 1
# 128511                0
# 126306                1
# 80809                 1
# 138096                0
# 65390                 1
# 64471                 1
# 54289                 1
# 153096                1
# 151098                0
# 55252                 1
# 155735                1
# 105006                0
# 163435                1
# 32311                 1
# 124629                1
# 167484                0
# 2622                  1
# 54329                 1
# 12935                 1
# 5355                  0
# 104581                1
# 103378                1
#
# [20000 rows x 10 columns]

# %%
#df = toys[['reviewText', 'positive_rating']]

# %%
toys['positive_rating'] = (toys['positive_rating'] == 1)

# %%
toys['reviewText'] = toys.reviewText.str.replace(r'[^a-zA-Z\d\s:]', '')
toys['reviewText'] = toys['reviewText'].str.lower()

pos_words = toys.reviewText[toys.overall].str.cat(sep=' ').split()

neg_words = toys.reviewText[toys.overall == False].str.cat(sep=' ').split()
# Out:
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\series.py:696: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]

# %%
# Unique Words
print('negative:', len(np.unique(neg_words)), ' positive:', len(np.unique(pos_words)))
# Out:
# negative: 0  positive: 23

# %%
keywords = pd.Series(neg_words).value_counts().keys().ravel()

keywords
# Out:
# array([], dtype=float64)

# %%
diff = np.setdiff1d(
        ar1=pd.Series(pos_words).value_counts().keys().ravel(), 
                      ar2=pd.Series(neg_words).value_counts().keys().ravel()
                     )
diff
# Out:
# array(['a', 'ago', 'and', 'bought', 'daughter', 'few', 'for', 'holidays',
#        'it', 'loved', 'loves', 'my', 'niece', 'one', 'our', 'she',
#        'still', 'the', 'today', 'too', 'using', 'we', 'years'],
#       dtype=object)

# %%
new = toys
keywords = diff

for key in keywords:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    new[str(key)] = new.reviewText.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

X = new[keywords]
y = new['positive_rating']

# %%
time1 = time.time()

# Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# Fit our model to the data.
bnb.fit(X, y)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(X)

# %%
cross_val_score(bnb, X, y, cv=5)
# Out:
# array([0.83654086, 0.8385    , 0.8365    , 0.83775   , 0.83845961])

# %%
print('Naive Bayes runtime')
print('--- %s seconds ---' % (time.time() - time1))

# %%
time2 = time.time()

from sklearn.svm import SVC
svc = SVC()

X = new[keywords]
y = new['positive_rating']

svc.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
cross_val_score(svc, X, y, cv=5)
# Out:
# array([0.8387903 , 0.83875   , 0.83875   , 0.83875   , 0.83895974])

# %%
print('SVM runtime')
print('--- %s seconds ---' % (time.time() - time2))

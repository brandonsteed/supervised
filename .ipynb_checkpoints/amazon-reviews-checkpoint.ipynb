# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
toys = pd.read_json('Toys_and_Games_5.json', lines=True)

# %%
toys
# Out:
#               asin   helpful  overall  \
# 0       0439893577    [0, 0]        5
# 1       0439893577    [1, 1]        4
# 2       0439893577    [1, 1]        5
# 3       0439893577    [0, 0]        5
# 4       0439893577    [1, 1]        4
# 5       0439893577    [0, 0]        3
# 6       0439893577    [0, 0]        3
# 7       0439893577    [1, 1]        5
# 8       0439893577    [0, 0]        4
# 9       0439893577  [59, 59]        3
# 10      0439893577    [0, 0]        5
# 11      0439893577    [2, 2]        5
# 12      0439893577    [0, 2]        3
# 13      0439893577    [0, 0]        5
# 14      0439893577  [17, 19]        5
# 15      0439893577    [3, 3]        5
# 16      0439893577    [0, 0]        5
# 17      048645195X    [0, 0]        5
# 18      048645195X    [2, 2]        4
# 19      048645195X    [7, 8]        5
# 20      048645195X  [11, 13]        5
# 21      048645195X    [0, 0]        5
# 22      048645195X    [1, 1]        5
# 23      048645195X    [0, 1]        5
# 24      048645195X    [0, 0]        5
# 25      048645195X    [1, 1]        3
# 26      048645195X    [5, 6]        3
# 27      048645195X    [0, 0]        4
# 28      0545496470    [0, 6]        4
# 29      0545496470   [5, 20]        3
# ...            ...       ...      ...
# 167567  B00KYMCJF8    [4, 6]        5
# 167568  B00KYMCJF8    [0, 0]        4
# 167569  B00KYMCJF8    [1, 2]        5
# 167570  B00KZAROWC    [0, 0]        5
# 167571  B00KZAROWC    [0, 0]        4
# 167572  B00KZAROWC    [1, 1]        2
# 167573  B00KZAROWC    [2, 2]        5
# 167574  B00KZAROWC    [1, 1]        5
# 167575  B00LBI9BKA    [0, 0]        5
# 167576  B00LBI9BKA    [0, 0]        5
# 167577  B00LBI9BKA    [0, 0]        5
# 167578  B00LBI9BKA    [0, 0]        5
# 167579  B00LBI9BKA    [0, 0]        5
# 167580  B00LBI9BKA    [0, 0]        5
# 167581  B00LBI9BKA    [1, 1]        5
# 167582  B00LBI9BKA    [0, 0]        5
# 167583  B00LBI9BKA    [0, 0]        5
# 167584  B00LBI9BKA    [0, 0]        5
# 167585  B00LBI9BKA    [0, 0]        5
# 167586  B00LBI9BKA    [0, 0]        5
# 167587  B00LBI9BKA    [0, 0]        4
# 167588  B00LBI9BKA    [0, 0]        5
# 167589  B00LBI9BKA    [0, 0]        5
# 167590  B00LBI9BKA    [0, 0]        5
# 167591  B00LBI9BKA    [0, 0]        5
# 167592  B00LBI9BKA    [0, 0]        5
# 167593  B00LBI9BKA    [1, 1]        5
# 167594  B00LBI9BKA    [0, 0]        5
# 167595  B00LBI9BKA    [0, 0]        5
# 167596  B00LBI9BKA    [0, 0]        4
#
#                                                reviewText   reviewTime  \
# 0       I like the item pricing. My granddaughter want...  01 29, 2014
# 1       Love the magnet easel... great for moving to d...  03 28, 2014
# 2       Both sides are magnetic.  A real plus when you...  01 28, 2013
# 167576                                 Worth every penny!      1405296000
# 167577                        Fantastic Stunt Helicopter!      1404864000
# 167578                                   Quadcopter Drone      1404777600
# 167579                                 Great play choice!      1404691200
# 167580                                          Good buy!      1404345600
# 167581                                               YES!      1404777600
# 167582  ... item all of the time I have so much fun pl...      1404864000
# 167583                        You Will Believe in UFO's!!      1404777600
# 167584                           Amazingly easy to handle      1405036800
# 167585  he absolutely loved it! He was able to make th...      1404345600
# 167586  A blast to use outside! A must have summer pro...      1404777600
# 167587                                         Four Stars      1404691200
# 167588                                             Great!      1404345600
# 167589                                Highly recommended!      1404345600
# 167590                                             5 star      1404259200
# 167591                                                  .      1404345600
# 167592                                           Very fun      1404691200
# 167593                          Coolest toy on the market      1404691200
# 167594                             A great idea for kids!      1404777600
# 167595                                    Excellent Drone      1405641600
# 167596                       Easy fun for the whole house      1405382400
#
# [167597 rows x 9 columns]

# %%
toys['overall'].hist()

# %%
toys['positive_rating'] = np.where(toys.overall >=4, 1, 0)

# %%
#df = toys[['reviewText', 'positive_rating']]

# %%
toys['positive_rating'] = (toys['positive_rating'] == 1)

# %%
toys['reviewText'] = toys.reviewText.str.replace(r'[^a-zA-Z\d\s:]', '')
toys['reviewText'] = toys['reviewText'].str.lower()

pos_words = toys.reviewText[toys.overall].str.cat(sep=' ').split()

neg_words = toys.reviewText[toys.overall == False].str.cat(sep=' ').split()

# %%
toys.reviewText[toys.overall].str.cat(sep=' ').split()
# Out:
# ['this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'i',
#  'have',
#  'a',
#  'stainless',
#  'steel',
#  'refrigerator',
#  'therefore',
#  'there',
#  'are',
#  'not',
#  'much',
#  'space',
#  'for',
#  'my',
#  'son',
#  'to',
#  'play',
#  'with',
#  'his',
#  'magnet',
#  'brought',
#  'this',
#  'for',
#  'him',
#  'to',
#  'put',
#  'his',
#  'magnet',
#  'on',
#  'he',
#  'enjoys',
#  'sticking',
#  'his',
#  'magnet',
#  'on',
#  'it',
#  'great',
#  'to',
#  'have',
#  'so',
#  'he',
#  'can',
#  'play',
#  'with',
#  'his',
#  'alphabet',
#  'magnets',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'i',
#  'have',
#  'a',
#  'stainless',
#  'steel',
#  'refrigerator',
#  'therefore',
#  'there',
#  'are',
#  'not',
#  'much',
#  'space',
#  'for',
#  'my',
#  'son',
#  'to',
#  'play',
#  'with',
#  'his',
#  'magnet',
#  'brought',
#  'this',
#  'for',
#  'him',
#  'to',
#  'put',
#  'his',
#  'magnet',
#  'on',
#  'he',
#  'enjoys',
#  'sticking',
#  'his',
#  'magnet',
#  'on',
#  'it',
#  'great',
#  'to',
#  'have',
#  'so',
#  'he',
#  'can',
#  'play',
#  'with',
#  'his',
#  'alphabet',
#  'magnets',
#  'bought',
#  'one',
#  'a',
#  'few',
#  'years',
#  'ago',
#  'for',
#  'my',
#  'daughter',
#  'and',
#  'she',
#  'loves',
#  'it',
#  'still',
#  'using',
#  'it',
#  'today',
#  'for',
#  'the',
#  'holidays',
#  'we',
#  'bought',
#  'one',
#  'for',
#  'our',
#  'niece',
#  'and',
#  'she',
#  'loved',
#  'it',
#  'too',
#  'bought',
#  'one',
#  'a',
#  'few',
#  'years',
#  'ago',
#  'for',
#  'my',
#  'daughter',
#  'and',
#  'she',
#  'loves',
#  'it',
#  'still',
#  'using',
#  'it',
#  'today',
#  'for',
#  'the',
#  'holidays',
#  'we',
#  'bought',
#  'one',
#  'for',
#  'our',
#  'niece',
#  'and',
#  'she',
#  'loved',
#  'it',
#  'too',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'i',
#  'have',
#  'a',
#  'stainless',
#  'steel',
#  'refrigerator',
#  'therefore',
#  'there',
#  'are',
#  'not',
#  'much',
#  'space',
#  'for',
#  'my',
#  'son',
#  'to',
#  'play',
#  'with',
#  'his',
#  'magnet',
#  'brought',
#  'this',
#  'for',
#  'him',
#  'to',
#  'put',
#  'his',
#  'magnet',
#  'on',
#  'he',
#  'enjoys',
#  'sticking',
#  'his',
#  'magnet',
#  'on',
#  'it',
#  'great',
#  'to',
#  'have',
#  'so',
#  'he',
#  'can',
#  'play',
#  'with',
#  'his',
#  'alphabet',
#  'magnets',
#  'bought',
#  'one',
#  'a',
#  'few',
#  'years',
#  'ago',
#  'for',
#  'my',
#  'daughter',
#  'and',
#  'she',
#  'loves',
#  'it',
#  'still',
#  'using',
#  'it',
#  'today',
#  'for',
#  'the',
#  'holidays',
#  'we',
#  'bought',
#  'one',
#  'for',
#  'our',
#  'niece',
#  'and',
#  'she',
#  'loved',
#  'it',
#  'too',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'bought',
#  'one',
#  'a',
#  'few',
#  'years',
#  'ago',
#  'for',
#  'my',
#  'daughter',
#  'and',
#  'she',
#  'loves',
#  'it',
#  'still',
#  'using',
#  'it',
#  'today',
#  'for',
#  'the',
#  'holidays',
#  'we',
#  'bought',
#  'one',
#  'for',
#  'our',
#  'niece',
#  'and',
#  'she',
#  'loved',
#  'it',
#  'too',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'i',
#  'have',
#  'a',
#  'stainless',
#  'steel',
#  'refrigerator',
#  'therefore',
#  'there',
#  'are',
#  'not',
#  'much',
#  'space',
#  'for',
#  'my',
#  'son',
#  'to',
#  'play',
#  'with',
#  'his',
#  'magnet',
#  'brought',
#  'this',
#  'for',
#  'him',
#  'to',
#  'put',
#  'his',
#  'magnet',
#  'on',
#  'he',
#  'enjoys',
#  'sticking',
#  'his',
#  'magnet',
#  'on',
#  'it',
#  'great',
#  'to',
#  'have',
#  'so',
#  'he',
#  'can',
#  'play',
#  'with',
#  'his',
#  'alphabet',
#  'magnets',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'this',
#  'is',
#  'a',
#  'nice',
#  'magnetic',
#  'board',
#  'for',
#  'the',
#  'kids',
#  'to',
#  'carry',
#  'around',
#  'and',
#  'play',
#  'with',
#  'the',
#  'letter',
#  'bought',
#  'additional',
#  'magnetic',
#  'pieces',
#  'from',
#  'mellissa',
#  'and',
#  'doug',
#  'to',
#  'increase',
#  'thier',
#  'play',
#  'time',
#  'with',
#  'them',
#  'hope',
#  'it',
#  'works',
#  'bought',
#  'one',
#  'a',
#  'few',
#  'years',
#  'ago',
#  'for',
#  'my',
#  'daughter',
#  'and',
#  'she',
#  'loves',
#  'it',
#  'still',
#  'using',
#  'it',
#  'today',
#  'for',
#  'the',
#  'holidays',
#  'we',
#  'bought',
#  'one',
#  'for',
#  'our',
#  'niece',
#  'and',
#  'she',
#  'loved',
#  'it',
#  'too',
#  'bought',
#  'one',
#  'a',
#  'few',
#  'years',
#  'ago',
#  'for',
#  'my',
#  'daughter',
#  'and',
#  'she',
#  'loves',
#  'it',
#  'still',
#  'using',
#  'it',
#  'today',
#  'for',
#  'the',
#  'holidays',
#  'we',
#  'bought',
#  'one',
#  'for',
#  'our',
#  'niece',
#  'and',
#  'she',
#  'loved',
#  'it',
#  'too',
#  'i',
#  'have',
#  'a',
#  'stainless',
#  'steel',
#  'refrigerator',
#  'therefore',
#  'there',
#  'are',
#  'not',
#  'much',
#  'space',
#  'for',
#  'my',
#  'son',
#  'to',
#  'play',
#  'with',
#  'his',
#  'magnet',
#  'brought',
#  'this',
#  'for',
#  'him',
#  'to',
#  'put',
#  'his',
#  'magnet',
#  'on',
#  'he',
#  'enjoys',
#  ...]

# %%
# Unique Words
print('negative:', len(np.unique(neg_words)), ' positive:', len(np.unique(pos_words)))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-d2b258e9a4e2> in <module>()
#       1 # Unique Words
# ----> 2 print('negative:', len(np.unique(neg_words)), ' positive:', len(np.unique(pos_words)))
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     221     ar = np.asanyarray(ar)
#     222     if axis is None:
# --> 223         return _unique1d(ar, return_index, return_inverse, return_counts)
#     224     if not (-ar.ndim <= axis < ar.ndim):
#     225         raise ValueError('Invalid axis kwarg specified for unique')
#
# c:\users\stacy steed\appdata\local\programs\python\python36-32\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     259     Find the unique elements of an array, ignoring shape.
#     260     """
# --> 261     ar = np.asanyarray(ar).flatten()
#     262
#     263     optional_indices = return_index or return_inverse
#
# MemoryError:

# %%
keywords = pd.Series(neg_words).value_counts().keys().ravel()

keywords

# %%
diff = np.setdiff1d(
        ar1=pd.Series(pos_words).value_counts().keys().ravel(), 
                      ar2=pd.Series(neg_words).value_counts().keys().ravel()
                     )
diff

# %%
new = toys
keywords = diff

for key in keywords:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    new[str(key)] = new.message.str.contains(
        ' ' + str(key) + ' ',
        case=False
    )

X = new[keywords]
y = new['positive_rating']

# %%
# Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# Classify, storing the result in a new variable; Fit our model to the data.
y_pred = bnb.fit(X, y).predict(data)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(bnb, X, y, cv=5)
